# %%
#import packages
import pandas as pd
import numpy as np

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df = pd.read_csv("m1010.csv")
# Out:
# /Users/cherielan/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (5,6,7,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#                                   skeyword  \
# 0                  dior+散粉|dior+眼影|dior+高光
# 1  dior+口红|dior+唇釉|dior+唇膏|dior+腮红|dior+眼影
# 2                                   ysl+口红
# 3                                  dior+高光
# 4                                   ysl+口红
#
#                                              content  \
# 0  我也来翻包之简洁实用熟女风  最近看到了好多少女风翻包，大家的收纳包和各种好物也都太粉嫩可爱...
# 1  2021爱用口红分享  唇妆类：  ①DHC唇膏打底保湿，日常护理都可以  ②Dior999...
# 2  YSL  YSL经典王牌416烂番茄色[赞R]  感觉我身边的小姐妹都基本人手一支了  色调...
# 3       【About Makeup】高光当然还是高光✨  Dior的高光还是很能打的  审美提升
# 4  日常口红分享  一口气入了四根口红，笑死，根本停不下来[捂脸R]  这四根口红都绝美，超越了...
#
#                                                  url  sentiment  \
# 0  https://www.xiaohongshu.com/discovery/item/60c...          1
# 1  https://www.xiaohongshu.com/discovery/item/604...          0
# 2  https://www.xiaohongshu.com/discovery/item/60d...          0
# 3  https://www.xiaohongshu.com/discovery/item/605...          0
# 4  https://www.xiaohongshu.com/discovery/item/607...          1
#
#              author gender                 author_id location  \
# 0             一颗意米球      女  5422367f6783e31e62805e32       北京
# 1              辣条毛线      女  5939f17e5e87e7200ad6078b       中国
# 2          小白甜Betty      女  5aae81cb4eacab3927df57cf   云南  昆明
# 3  李小野Makeup-Artist      女  5a24187611be105a71dee086   北京 朝阳区
# 4               淡藤透      女  5b584179e8ac2b55344bb4d1      NaN
#
#                      keywd                   item_id  ... inspiration gift  \
# 0           便携|散粉|气垫|照片|粉霜  60c60723000000000102d8ac  ...           0    0
# 1         口红|唇膏|展示柜|粉色|红棕色  6041eb2200000000010291f1  ...           0    0
# 2          人手|口红|王牌|色调|阿玛尼  60d5685c00000000010294d9  ...           0    0
# 3  About|Dior|Makeup|审美|高光  6058b65b000000000102f2ba  ...           0    0
# 4         口红|圆管|枣泥|植村秀|玫瑰色  6076f05a000000000102b5ed  ...           0    0
#
#   luxury price channel lifestyle service  occasion  limited   group2
# 0      0     1       0         0       0         1        0  couture
# 1      1     0       0         0       0         0        0  couture
# 2      0     0       0         0       0         0        0  couture
# 3      0     0       0         0       0         0        0  couture
# 4      0     0       0         0       0         0        1  couture
#
# [5 rows x 49 columns]

# %% [raw]
# df.columns

# %%
dftest = df[(df['category2'] == "makeup")&(df['group2'] == "prestige")] 

##按照行的条件筛选 slice with conditions

# %%
dftest.shape
# Out:
# (113494, 49)

# %%
columnx=[ 'brandname', 'celebrity', 'brandheritage',
       'brandvalue', 'design', 'logo', 'quality', 'rd', 'team', 'innovation',
       'format', 'color', 'look', 'efficacy', 'ingredients', 'sensorial',
       'fragrance', 'texture', 'application', 'convenience', 'concept',
       'aesthetic', 'inspiration', 'gift', 'luxury', 'price', 'channel',
       'lifestyle', 'service', 'occasion', 'limited']

# %%
df2=pd.DataFrame(dftest, columns = columnx)

# %%
#can be changed:  min_support=0.07
frequent_itemsets = apriori(df2, min_support=0.02, use_colnames=True, max_len = 2)
rules = association_rules(frequent_itemsets, metric='lift', min_threshold=1)
rules.sort_values('lift',ascending = False).head(50)
# Out:
#        antecedents    consequents  antecedent support  consequent support  \
# 80        (format)      (service)            0.134113            0.063122
# 81       (service)       (format)            0.063122            0.134113
# 201    (aesthetic)       (luxury)            0.136254            0.056223
# 200       (luxury)    (aesthetic)            0.056223            0.136254
# 158    (aesthetic)  (ingredients)            0.136254            0.088498
# 159  (ingredients)    (aesthetic)            0.088498            0.136254
# 165      (texture)    (sensorial)            0.181490            0.240118
# 164    (sensorial)      (texture)            0.240118            0.181490
# 189      (texture)       (luxury)            0.181490            0.056223
# 188       (luxury)      (texture)            0.056223            0.181490
# 58     (aesthetic)   (innovation)            0.136254            0.055351
# 59    (innovation)    (aesthetic)            0.055351            0.136254
# 182      (texture)  (application)            0.181490            0.125919
# 183  (application)      (texture)            0.125919            0.181490
# 156  (ingredients)  (application)            0.088498            0.125919
# 157  (application)  (ingredients)            0.125919            0.088498
# 47        (design)       (luxury)            0.189940            0.056223
# 46        (luxury)       (design)            0.056223            0.189940
# 16     (brandname)        (price)            0.094490            0.154317
# 17         (price)    (brandname)            0.154317            0.094490
# 207        (price)      (channel)            0.154317            0.084841
# 206      (channel)        (price)            0.084841            0.154317
# 154      (texture)  (ingredients)            0.181490            0.088498
# 155  (ingredients)      (texture)            0.088498            0.181490
# 79       (channel)       (format)            0.084841            0.134113
# 78        (format)      (channel)            0.134113            0.084841
# 167  (application)    (sensorial)            0.125919            0.240118
# 166    (sensorial)  (application)            0.240118            0.125919
# 197  (application)    (aesthetic)            0.125919            0.136254
# 196    (aesthetic)  (application)            0.136254            0.125919
# 180      (texture)    (fragrance)            0.181490            0.062717
# 181    (fragrance)      (texture)            0.062717            0.181490
# 185      (texture)    (aesthetic)            0.181490            0.136254
# 184    (aesthetic)      (texture)            0.136254            0.181490
# 173    (sensorial)       (luxury)            0.240118            0.056223
# 172       (luxury)    (sensorial)            0.056223            0.240118
# 195     (occasion)      (texture)            0.052443            0.181490
# 194      (texture)     (occasion)            0.181490            0.052443
# 152    (sensorial)  (ingredients)            0.240118            0.088498
# 153  (ingredients)    (sensorial)            0.088498            0.240118
# 162    (sensorial)    (fragrance)            0.240118            0.062717
# 163    (fragrance)    (sensorial)            0.062717            0.240118
# 3         (format)    (brandname)            0.134113            0.094490
# 2      (brandname)       (format)            0.094490            0.134113
# 15     (aesthetic)    (brandname)            0.136254            0.094490
# 14     (brandname)    (aesthetic)            0.094490            0.136254
# 37     (fragrance)       (design)            0.062717            0.189940
# 36        (design)    (fragrance)            0.189940            0.062717
# 138     (efficacy)      (texture)            0.332291            0.181490
# 139      (texture)     (efficacy)            0.181490            0.332291
#
#       support  confidence      lift  leverage  conviction
# 80   0.031182    0.232508  3.683449  0.022717    1.220700
# 81   0.031182    0.493998  3.683449  0.022717    1.711232
